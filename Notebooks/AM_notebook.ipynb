# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
ev_stations = pd.read_csv("../data/alt_fuel_stations.csv")
# Out:
# C:\Users\armat\AppData\Local\Temp\ipykernel_25220\1331630876.py:1: DtypeWarning: Columns (6,20,31,46,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   ev_stations = pd.read_csv("../data/alt_fuel_stations.csv")

# %%
clean_stations = ev_stations.drop(columns={"Plus4", "Expected Date", "BD Blends", "NG Fill Type Code", "NG PSI", "Federal Agency ID", "Federal Agency Name", "Hydrogen Status Link", "NG Vehicle Class", "LPG Primary", "E85 Blender Pump", "Intersection Directions (French)", "Access Days Time (French)", "BD Blends", "Hydrogen Is Retail", "Federal Agency Code", "CNG Dispenser Num", "CNG On-Site Renewable Source", "CNG Total Compression Capacity", "CNG Storage Capacity", "LNG On-Site Renewable Source", "E85 Other Ethanol Blends", "EV Pricing (French)", "LPG Nozzle Types", "Hydrogen Pressures", "Hydrogen Standards", "CNG Fill Type Code", "CNG PSI", "CNG Vehicle Class", "LNG Vehicle Class"})

# %%
stations_less_columns = clean_stations.drop(columns={"Intersection Directions", "RD Blends", "RD Blended with Biodiesel", "RD Maximum Biodiesel Level", "NPS Unit Name", "CNG Station Sells Renewable Natural Gas", "LNG Station Sells Renewable Natural Gas", "Maximum Vehicle Class"})
ev_clean_stations = stations_less_columns.drop(columns={"BD Blends (French)", "Access Code", "Access Detail Code", "EV On-Site Renewable Source", "Restricted Access", "RD Blends (French)", "Groups With Access Code (French)"})
ev_clean_stations
# Out:
#       Fuel Type Code                                       Station Name  \
# 0               ELEC                      Los Angeles Convention Center
# 1               ELEC                     California Air Resources Board
# 2               ELEC                             Scripps Green Hospital
# 3               ELEC                                      Galpin Motors
# 4               ELEC                                  Galleria at Tyler
# ...              ...                                                ...
# 62322           ELEC                            Riverview - 17th Ave SW
# 62323           ELEC  Kapolei Commons provided by Hawaiian Electric ...
# 62324           ELEC                    Orange County Health Department
# 62325           ELEC  Cedar Fair Entertainment Company 14523 Carowin...
# 62326           ELEC                      AMC Highland 12 East Entrance
#
#                   Street Address         City State    ZIP Station Phone  \
# 0             1201 S Figueroa St  Los Angeles    CA  90015  213-741-1151
# 1               9530 Telstar Ave     El Monte    CA  91731  626-575-6800
# 2        10666 N Torrey Pines Rd     La Jolla    CA  92037           NaN
# 3              15421 Roscoe Blvd    Sepulveda    CA  91343  800-256-6219
# 4         1299 Galleria at Tyler    Riverside    CA  92503  951-351-3110
# ...                          ...          ...   ...    ...           ...
# 62322           7021 17th Ave SW      Seattle    WA  98106  855-900-7584
# 62323       4470 Kapolei Parkway      Kapolei    HI  96707  855-885-9571
# 62324        12050 E Colonial Dr      Orlando    FL  32826  866-816-7584
# 62325  14523 Carowinds Boulevard    Charlotte    SC  28273  888-264-2208
# 62326       1181 S Jefferson Ave   Cookeville    TN  38506  888-264-2208
#
#       Status Code Groups With Access Code  \
# 0               E                  Public
# 1               E                  Public
# 2               E                  Public
# 3               E     Public - Call ahead
# 4               E                  Public
# ...           ...                     ...
# 62322           E                  Public
# 62323           E                  Public
# 62324           E                  Public
# 62325           E                  Public
# 62326           E                  Public
#
#                                         Access Days Time  ...  \
# 0                                    5:30am-9pm; pay lot  ...
# 1                                         24 hours daily  ...
# 2                                         24 hours daily  ...
# 3           Dealership business hours; customer use only  ...
# 4                                         6am-12am daily  ...
# ...                                                  ...  ...
# 62322                                     24 hours daily  ...
# 62323                                                NaN  ...
# 62324                                                NaN  ...
# 62325  Mon 5:00am - 10:59pm; Tue 5:00am - 10:59pm; We...  ...
# 62326  Mon 5:00am - 10:59pm; Tue 5:00am - 10:59pm; We...  ...
#
#       Date Last Confirmed      ID               Updated At  Owner Type Code  \
# 0              2023-01-10    1523  2023-02-14 15:54:11 UTC                P
# 1              2022-09-14    1583  2023-02-14 15:54:11 UTC               SG
# 2              2023-01-10    6355  2023-02-14 15:54:11 UTC                P
# 3              2023-08-10    6405  2024-01-31 22:07:01 UTC                P
# 4              2023-09-14    6425  2024-01-31 22:07:01 UTC                P
# ...                   ...     ...                      ...              ...
# 62322          2024-04-02  331532  2024-04-02 02:18:25 UTC              NaN
# 62323          2024-04-02  331533  2024-04-02 02:25:15 UTC              NaN
# 62324          2024-04-02  331535  2024-04-02 02:29:34 UTC              NaN
# 62325          2024-04-02  331537  2024-04-02 02:33:28 UTC              NaN
# 62326          2024-04-02  331538  2024-04-02 02:35:44 UTC              NaN
#
#         Open Date  EV Connector Types Country   Facility Type  \
# 0      1995-08-30               J1772      US  PARKING_GARAGE
# 1      1996-10-15               J1772      US       STATE_GOV
# 2      1997-07-30               J1772      US        HOSPITAL
# 3      2012-12-11               J1772      US      CAR_DEALER
# 4      1997-08-30               J1772      US   SHOPPING_MALL
# ...           ...                 ...     ...             ...
# 62322  2024-04-02               J1772      US             NaN
# 62323  2024-04-02  CHADEMO J1772COMBO      US             NaN
# 62324  2024-04-02  CHADEMO J1772COMBO      US             NaN
# 62325  2024-04-02               J1772      US             NaN
# 62326  2024-04-02               J1772      US             NaN
#
#               EV Pricing  EV Workplace Charging
# 0      Free; parking fee                  False
# 1                   Free                  False
# 2      Free; parking fee                  False
# 3                    NaN                  False
# 4                   Free                  False
# ...                  ...                    ...
# 62322                NaN                  False
# 62323                NaN                  False
# 62324                NaN                  False
# 62325                NaN                  False
# 62326                NaN                  False
#
# [62327 rows x 30 columns]

# %%
ev_filled = ev_clean_stations.fillna(0)
full_and_clean = ev_filled.rename(columns={
    "Station Phone": "Phone Number",
    "Groups With Access Code": "Who Can Access",
    "Access Days Time": "Hours of Operation",
    "Cards Accepted": "Cards Accepted?",
    "EV Level1 EVSE Num": "# of EV Level 1 Chargers",
    "EV Level2 EVSE Num": "# of EV Level 2 Chargers",
    "EV DC Fast Count": "# of DC EV Chargers",
    "EV Network Web": "EV Network Website"})

# %%
full_and_clean.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address', 'City', 'State',
#        'ZIP', 'Phone Number', 'Status Code', 'Who Can Access',
#        'Hours of Operation', 'Cards Accepted?', '# of EV Level 1 Chargers',
#        '# of EV Level 2 Chargers', '# of DC EV Chargers', 'EV Other Info',
#        'EV Network', 'EV Network Website', 'Geocode Status', 'Latitude',
#        'Longitude', 'Date Last Confirmed', 'ID', 'Updated At',
#        'Owner Type Code', 'Open Date', 'EV Connector Types', 'Country',
#        'Facility Type', 'EV Pricing', 'EV Workplace Charging'],
#       dtype='object')

# %%
full_and_clean.to_csv("../output/cleaned_stations.csv")

# %%
car_data = pd.read_csv("../data/output.csv")

# %%
mean_range = car_data["Range (miles)"].mean()
mean_range
# Out:
# 210.51456310679612

# %%
stations_by_network = full_and_clean.groupby(full_and_clean["State"])["Station Name"].count()
stations_by_network.plot(kind="bar")
plt.xlabel('EV Network')
plt.ylabel('Station Counts')
plt.title('Stations by State')
plt.figure(figsize=(200, 8))
plt.tight_layout()
plt.show()
plt.savefig("../output/stations_by_state.png")

# %%
charger_df = pd.read_csv("../data/charger_data.csv")

# %%
charger_df.columns
# Out:
# Index([' Year ', ' EV Charging Ports ', ' Station Locations '], dtype='object')

# %%
# charger_df[' EV Charging Ports '] = charger_df[' EV Charging Ports '].str.replace(',', '')
# charger_df[' Station Locations '] = charger_df[' Station Locations '].str.replace(',', '')
charger_df[' EV Charging Ports '] = pd.to_numeric(charger_df[' EV Charging Ports '])
charger_df[' Station Locations '] = pd.to_numeric(charger_df[' Station Locations '])
bar_width = 0.35
plt.bar(charger_df[' Year '], charger_df[' EV Charging Ports '], width=bar_width, label='EV Charging Ports ')
plt.bar(charger_df[' Year '] + bar_width, charger_df[' Station Locations '], width=bar_width, label='Station Locations ')
plt.xlabel('Year')
plt.ylabel('Values')
plt.title('Number of Station Locations and Charging Ports in US')
plt.legend()
plt.savefig("../output/station_graph.png")

# %%
charger_df.to_csv("../output/us_ev_stations.csv")

# %%
sales_df = pd.read_csv("../data/sales_data.csv")

# %%
sales_df.columns
# Out:
# Index(['Vehicle', 'Type', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', 'Total'],
#       dtype='object')

# %%
# Loop through the years
for i in range(2011, 2020):
    str_val = '{}'.format(i)
    # Remove non-numeric characters
    sales_df[str_val] = sales_df[str_val].replace(r'[^0-9]+', '', regex=True)
    # Replace empty strings with '0'
    sales_df[str_val] = sales_df[str_val].replace('', '0')

sales_df.head()
# Out:
#            Vehicle  Type  2011   2012   2013   2014   2015   2016   2017  \
# 0       Chevy Volt  PHEV  7671  23461  23094  18805  15393  24739  20349
# 1      Nissan Leaf    EV  9674   9819  22610  30200  17269  14006  11230
# 2         Smart ED    EV   342    139    923   2594   1387    657    544
# 3  Mitsubishi I EV    EV    76    588   1029    196    115     94      6
# 4     BMW Active E    EV     0    673      0      0      0      0      0
#
#     2018   2019    Total
# 0  18306   4915  156,733
# 1  14715  12365  141,888
# 2   1219    680    8,485
# 3      0      0    2,104
# 4      0      0      673

# %%
# Convert columns '2011' to '2019' to numeric
sales_df.loc[:, '2011':'2019'] = sales_df.loc[:, '2011':'2019'].apply(pd.to_numeric, errors='coerce')

# Recalculate "Total" by summing up data from columns '2011' to '2019'
sales_df['Total'] = sales_df.loc[:, '2011':'2019'].sum(axis=1)

# Now, columns '2011' to '2019' have been converted to numeric type, and "Total" has been recalculated based on the sum of these numeric columns
sales_df
# Out:
#                              Vehicle  Type   2011   2012   2013    2014  \
# 0                         Chevy Volt  PHEV   7671  23461  23094   18805
# 1                        Nissan Leaf    EV   9674   9819  22610   30200
# 2                           Smart ED    EV    342    139    923    2594
# 3                    Mitsubishi I EV    EV     76    588   1029     196
# 4                       BMW Active E    EV      0    673      0       0
# 5                         Prius PHEV  PHEV      0  12749  12088   13264
# 6                      Ford Focus EV    EV      0    683   1738    1964
# 7                       Honda Fit EV    EV      0     93    569     407
# 8                      Tesla Model S    EV      0   2400  19400   16750
# 9                     Toyota RAV4 EV    EV      0    192   1005    1184
# 10                 Ford C-Max Energi  PHEV      0   2374   7154    8433
# 11                      Honda Accord  PHEV      0      0    526     449
# 12                Ford Fusion Energi  PHEV      0      0   6089   11550
# 13                       Chevy Spark    EV      0      0    560    1145
# 14                         Fiat 500E    EV      0      0    260    1503
# 15       Porsche Panamera S E-Hybrid  PHEV      0      0     51     879
# 16                      Cadillac ELR  PHEV      0      0      6    1310
# 17                            BMW i3    EV      0      0      0    6092
# 18          Mercedes B-Class (B250e)    EV      0      0      0     774
# 19                            BMW i8  PHEV      0      0      0     555
# 20                         VW e-Golf    EV      0      0      0     357
# 21                       Kia Soul EV    EV      0      0      0     359
# 22        Porsche Cayenne S E-Hybrid  PHEV      0      0      0     112
# 23                Mercedes S550 Plug  PHEV      0      0      0       0
# 24                Volvo-XC90 Plug In  PHEV      0      0      0       0
# 25                     Tesla Model X    EV      0      0      0       0
# 26                            BMW X5  PHEV      0      0      0       0
# 27            Hyundai Sonata Plug In  PHEV      0      0      0       0
# 28                   Audi A3 Plug In  PHEV      0      0      0       0
# 29              BMW 3-series Plug-In  PHEV      0      0      0       0
# 30                 Mercedes GLE 550e  PHEV      0      0      0       0
# 31              BMW 7-series Plug-in  PHEV      0      0      0       0
# 32                   Mercedes C350We  PHEV      0      0      0       0
# 33                        Chevy Bolt    EV      0      0      0       0
# 34                Kia Optima Plug-in  PHEV      0      0      0       0
# 35                  Hyundai Ioniq EV    EV      0      0      0       0
# 36  Chrysler Pacifica Plug-in Hybrid  PHEV      0      0      0       0
# 37                      Cadillac CT6  PHEV      0      0      0       0
# 38              BMW 5-Series Plug in  PHEV      0      0      0       0
# 39               MINI Countryman S E  PHEV      0      0      0       0
# 40            Porsche Panamera 4 E-H  PHEV      0      0      0       0
# 41                     Tesla Model 3    EV      0      0      0       0
# 42                 Honda Clarity BEV    EV      0      0      0       0
# 43                Volvo XC60 Plug In  PHEV      0      0      0       0
# 44                 Volvo S90 Plug In  PHEV      0      0      0       0
# 45             Honda Clarity Plug-in  PHEV      0      0      0       0
# 46      Mitsubishi Outlander Plug In  PHEV      0      0      0       0
# 47             Hyundai Ioniq Plug-In  PHEV      0      0      0       0
# 48                  Kia Niro Plug In  PHEV      0      0      0       0
# 49          Mercedes GLC 350e Hybrid  PHEV      0      0      0       0
# 50                     Jaguar I-Pace    EV      0      0      0       0
# 51             Hyundai Kona Electric    EV      0      0      0       0
# 52           Subaru Crosstrek Hybrid  PHEV      0      0      0       0
# 53                       Audi e-tron    EV      0      0      0       0
# 54                       Kia Niro EV    EV      0      0      0       0
# 55                             Total   NaN  17763  53171  97102  118882
#
#       2015    2016    2017    2018    2019    Total
# 0    15393   24739   20349   18306    4915   156733
# 1    17269   14006   11230   14715   12365   141888
# 2     1387     657     544    1219     680     8485
# 3      115      94       6       0       0     2104
# 4        0       0       0       0       0      673
# 5     4191    2474   20936   27595   23630   116927
# 6     1582     901    1817     560       0     9245
# 7        2       0       0       0       0     1071
# 8    26200   30200   26500   25745   15090   162285
# 9       18       0       0       0       0     2399
# 10    7591    7957    8140     582       0    42231
# 11      64       0       0       0       0     1039
# 12    9750   15938    9632    8074    7476    68509
# 13    2629    3035      23       7       0     7399
# 14    3477    3737    3336    2250     632    15195
# 15     407     393      18    2036    1958     5742
# 16    1024     534      17       1       0     2892
# 17   11024    7625    6276    6117    4854    41988
# 18    1906     632     744     135       9     4200
# 19    2265    1594     488     772    1102     6776
# 20    4232    3937    3534    1354    4863    18277
# 21    1015    1728    2157    1134     114     6507
# 22    1163    2111    1574    1022    1140     7122
# 23     118     550     666      96     371     1801
# 24      86    2015    2358    1387    1710     7556
# 25     208   19600   21700   26100   19425    87033
# 26     892    5995    5349    4434     167    16837
# 27      15    3000    2254     460     456     6185
# 28       0    4280    2877    2597     437    10191
# 29       0     880    4141    2600     705     8326
# 30       0     231     463     966    1509     3169
# 31       0      23     707     339      80     1149
# 32       0     171     817    1721    2172     4881
# 33       0     579   23297   18019   16313    58208
# 34       0       0    1512     965     350     2827
# 35       0       0     432     345     739     1516
# 36       0       0    2981    7062    5811    15854
# 37       0       0     205     231      25      461
# 38       0       0    3759    8664    5442    17865
# 39       0       0     475    1564     494     2533
# 40       0       0       0       0       0        0
# 41       0       0    1770  139782  154840   296392
# 42       0       0    1126     948     742     2816
# 43       0       0     356    2267    1682     4305
# 44       0       0     112     437     407      956
# 45       0       0     903   18602   10728    30233
# 46       0       0       0    4166    2810     6976
# 47       0       0       0    1590    1765     3355
# 48       0       0       0    3389    4051     7440
# 49       0       0       0     567    2459     3026
# 50       0       0       0     393    2594     2987
# 51       0       0       0       0    1721     1721
# 52       0       0       0       0     880      880
# 53       0       0       0       0    5369     5369
# 54       0       0       0       0    1562     1562
# 55  114023  159616  195581  361315  326644  1444097

# %%
sales_data = sales_df.dropna()
sales_data_no_total = sales_data.drop(columns="Total")
sales_data_no_total
# Out:
#                              Vehicle  Type  2011   2012   2013   2014   2015  \
# 0                         Chevy Volt  PHEV  7671  23461  23094  18805  15393
# 1                        Nissan Leaf    EV  9674   9819  22610  30200  17269
# 2                           Smart ED    EV   342    139    923   2594   1387
# 3                    Mitsubishi I EV    EV    76    588   1029    196    115
# 4                       BMW Active E    EV     0    673      0      0      0
# 5                         Prius PHEV  PHEV     0  12749  12088  13264   4191
# 6                      Ford Focus EV    EV     0    683   1738   1964   1582
# 7                       Honda Fit EV    EV     0     93    569    407      2
# 8                      Tesla Model S    EV     0   2400  19400  16750  26200
# 9                     Toyota RAV4 EV    EV     0    192   1005   1184     18
# 10                 Ford C-Max Energi  PHEV     0   2374   7154   8433   7591
# 11                      Honda Accord  PHEV     0      0    526    449     64
# 12                Ford Fusion Energi  PHEV     0      0   6089  11550   9750
# 13                       Chevy Spark    EV     0      0    560   1145   2629
# 14                         Fiat 500E    EV     0      0    260   1503   3477
# 15       Porsche Panamera S E-Hybrid  PHEV     0      0     51    879    407
# 16                      Cadillac ELR  PHEV     0      0      6   1310   1024
# 17                            BMW i3    EV     0      0      0   6092  11024
# 18          Mercedes B-Class (B250e)    EV     0      0      0    774   1906
# 19                            BMW i8  PHEV     0      0      0    555   2265
# 20                         VW e-Golf    EV     0      0      0    357   4232
# 21                       Kia Soul EV    EV     0      0      0    359   1015
# 22        Porsche Cayenne S E-Hybrid  PHEV     0      0      0    112   1163
# 23                Mercedes S550 Plug  PHEV     0      0      0      0    118
# 24                Volvo-XC90 Plug In  PHEV     0      0      0      0     86
# 25                     Tesla Model X    EV     0      0      0      0    208
# 26                            BMW X5  PHEV     0      0      0      0    892
# 27            Hyundai Sonata Plug In  PHEV     0      0      0      0     15
# 28                   Audi A3 Plug In  PHEV     0      0      0      0      0
# 29              BMW 3-series Plug-In  PHEV     0      0      0      0      0
# 30                 Mercedes GLE 550e  PHEV     0      0      0      0      0
# 31              BMW 7-series Plug-in  PHEV     0      0      0      0      0
# 32                   Mercedes C350We  PHEV     0      0      0      0      0
# 33                        Chevy Bolt    EV     0      0      0      0      0
# 34                Kia Optima Plug-in  PHEV     0      0      0      0      0
# 35                  Hyundai Ioniq EV    EV     0      0      0      0      0
# 36  Chrysler Pacifica Plug-in Hybrid  PHEV     0      0      0      0      0
# 37                      Cadillac CT6  PHEV     0      0      0      0      0
# 38              BMW 5-Series Plug in  PHEV     0      0      0      0      0
# 39               MINI Countryman S E  PHEV     0      0      0      0      0
# 40            Porsche Panamera 4 E-H  PHEV     0      0      0      0      0
# 41                     Tesla Model 3    EV     0      0      0      0      0
# 42                 Honda Clarity BEV    EV     0      0      0      0      0
# 43                Volvo XC60 Plug In  PHEV     0      0      0      0      0
# 44                 Volvo S90 Plug In  PHEV     0      0      0      0      0
# 45             Honda Clarity Plug-in  PHEV     0      0      0      0      0
# 46      Mitsubishi Outlander Plug In  PHEV     0      0      0      0      0
# 47             Hyundai Ioniq Plug-In  PHEV     0      0      0      0      0
# 48                  Kia Niro Plug In  PHEV     0      0      0      0      0
# 49          Mercedes GLC 350e Hybrid  PHEV     0      0      0      0      0
# 50                     Jaguar I-Pace    EV     0      0      0      0      0
# 51             Hyundai Kona Electric    EV     0      0      0      0      0
# 52           Subaru Crosstrek Hybrid  PHEV     0      0      0      0      0
# 53                       Audi e-tron    EV     0      0      0      0      0
# 54                       Kia Niro EV    EV     0      0      0      0      0
#
#      2016   2017    2018    2019
# 0   24739  20349   18306    4915
# 1   14006  11230   14715   12365
# 2     657    544    1219     680
# 3      94      6       0       0
# 4       0      0       0       0
# 5    2474  20936   27595   23630
# 6     901   1817     560       0
# 7       0      0       0       0
# 8   30200  26500   25745   15090
# 9       0      0       0       0
# 10   7957   8140     582       0
# 11      0      0       0       0
# 12  15938   9632    8074    7476
# 13   3035     23       7       0
# 14   3737   3336    2250     632
# 15    393     18    2036    1958
# 16    534     17       1       0
# 17   7625   6276    6117    4854
# 18    632    744     135       9
# 19   1594    488     772    1102
# 20   3937   3534    1354    4863
# 21   1728   2157    1134     114
# 22   2111   1574    1022    1140
# 23    550    666      96     371
# 24   2015   2358    1387    1710
# 25  19600  21700   26100   19425
# 26   5995   5349    4434     167
# 27   3000   2254     460     456
# 28   4280   2877    2597     437
# 29    880   4141    2600     705
# 30    231    463     966    1509
# 31     23    707     339      80
# 32    171    817    1721    2172
# 33    579  23297   18019   16313
# 34      0   1512     965     350
# 35      0    432     345     739
# 36      0   2981    7062    5811
# 37      0    205     231      25
# 38      0   3759    8664    5442
# 39      0    475    1564     494
# 40      0      0       0       0
# 41      0   1770  139782  154840
# 42      0   1126     948     742
# 43      0    356    2267    1682
# 44      0    112     437     407
# 45      0    903   18602   10728
# 46      0      0    4166    2810
# 47      0      0    1590    1765
# 48      0      0    3389    4051
# 49      0      0     567    2459
# 50      0      0     393    2594
# 51      0      0       0    1721
# 52      0      0       0     880
# 53      0      0       0    5369
# 54      0      0       0    1562

# %%
sales_data_no_total.to_csv("../output/ev_sales.csv")

# %%
years = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
sums = sales_data_no_total.loc[:, years].sum(axis=0)
plt.plot(years, sums, marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Total Sales')
plt.title('Total Sales of Vehicles per Year')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
plt.savefig("../output/ev_sales.png")
