# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Read the csv file using Pandas
df = pd.read_csv('ElectricCarData_Clean.csv')

# %%
# Display the first 50 rows
df.head(50)
# Out:
#           Brand                           Model  AccelSec  TopSpeed_KmH  \
# 0        Tesla    Model 3 Long Range Dual Motor       4.6           233
# 1   Volkswagen                        ID.3 Pure      10.0           160
# 2     Polestar                                2       4.7           210
# 3          BMW                             iX3        6.8           180
# 4        Honda                               e        9.5           145
# 5        Lucid                             Air        2.8           250
# 6   Volkswagen                          e-Golf        9.6           150
# 7      Peugeot                           e-208        8.1           150
# 8        Tesla      Model 3 Standard Range Plus       5.6           225
# 9         Audi                       Q4 e-tron        6.3           180
# 10    Mercedes                   EQC 400 4MATIC       5.1           180
# 11      Nissan                            Leaf        7.9           144
# ...

# %%
# Convert TopSpeed_KmH column to MpH and change the column name
convert_to_mph = 0.621371
df['TopSpeed_KmH'] = (df['TopSpeed_KmH'] * convert_to_mph).round()
df = df.rename(columns={'TopSpeed_KmH': 'Top Speed MPH'})
# Display the new dataframe
df.head(10)
# Out:
#          Brand                          Model  AccelSec  Top Speed MPH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6          145.0
# 1  Volkswagen                       ID.3 Pure      10.0           99.0
# 2    Polestar                               2       4.7          130.0
# 3         BMW                            iX3        6.8          112.0
# 4       Honda                              e        9.5           90.0
# 5       Lucid                            Air        2.8          155.0
# 6  Volkswagen                         e-Golf        9.6           93.0
# 7     Peugeot                          e-208        8.1           93.0
# 8       Tesla     Model 3 Standard Range Plus       5.6          140.0
# 9        Audi                      Q4 e-tron        6.3          112.0
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# ...

# %%
convert_to_miles = 0.621371
df['Range_Km'] = (df['Range_Km'] * convert_to_miles).round()
df = df.rename(columns={'Range_Km': 'Range (miles)'})
df.head()
# Out:
#          Brand                          Model  AccelSec  Top Speed MPH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6          145.0
# 1  Volkswagen                       ID.3 Pure      10.0           99.0
# 2    Polestar                               2       4.7          130.0
# 3         BMW                            iX3        6.8          112.0
# 4       Honda                              e        9.5           90.0
#
#    Range (miles)  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0          280.0              161            940         Yes        AWD
# 1          168.0              167            250         Yes        RWD
# 2          249.0              181            620         Yes        AWD
# 3          224.0              206            560         Yes        RWD
# 4          106.0              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# ...

# %%
# Update the currency columns to USD and change the name of the column
currency_update = 1.08
df['PriceEuro'] = (df['PriceEuro'] * currency_update)
df = df.rename(columns={'PriceEuro': 'Price (USD)'})
df.head(20)
# Out:
#           Brand                          Model  AccelSec  Top Speed MPH  \
# 0        Tesla   Model 3 Long Range Dual Motor       4.6          145.0
# 1   Volkswagen                       ID.3 Pure      10.0           99.0
# 2     Polestar                               2       4.7          130.0
# 3          BMW                            iX3        6.8          112.0
# 4        Honda                              e        9.5           90.0
# 5        Lucid                            Air        2.8          155.0
# 6   Volkswagen                         e-Golf        9.6           93.0
# 7      Peugeot                          e-208        8.1           93.0
# 8        Tesla     Model 3 Standard Range Plus       5.6          140.0
# 9         Audi                      Q4 e-tron        6.3          112.0
# 10    Mercedes                  EQC 400 4MATIC       5.1          112.0
# 11      Nissan                           Leaf        7.9           89.0
# ...

# %%
# Update the Efficiency_WhKm coloumn to an Imperial measurement and change the name of the column
df['Efficiency_WhKm'] = (df['Efficiency_WhKm'] * convert_to_miles).round()
df = df.rename(columns={'Efficiency_WhKm': 'Efficiency WhM'})
df.head(20)
# Out:
#           Brand                          Model  AccelSec  Top Speed MPH  \
# 0        Tesla   Model 3 Long Range Dual Motor       4.6          145.0
# 1   Volkswagen                       ID.3 Pure      10.0           99.0
# 2     Polestar                               2       4.7          130.0
# 3          BMW                            iX3        6.8          112.0
# 4        Honda                              e        9.5           90.0
# 5        Lucid                            Air        2.8          155.0
# 6   Volkswagen                         e-Golf        9.6           93.0
# 7      Peugeot                          e-208        8.1           93.0
# 8        Tesla     Model 3 Standard Range Plus       5.6          140.0
# 9         Audi                      Q4 e-tron        6.3          112.0
# 10    Mercedes                  EQC 400 4MATIC       5.1          112.0
# 11      Nissan                           Leaf        7.9           89.0
# ...

# %%
# Convert all values in FastCharge_KmH from '-' to NaN 
df['FastCharge_KmH'] = df['FastCharge_KmH'].replace('-', np.nan)

# Replacing Null values in FastCharge_KmH column to 0
df['FastCharge_KmH'].fillna(1, inplace= True)



df.tail(50)
# Out:
#            Brand                            Model  AccelSec  Top Speed MPH  \
# 53        Skoda                       Enyaq iV 80       8.8           99.0
# 54        Tesla                Model X Long Range       4.6          155.0
# 55        Honda                         e Advance       8.3           90.0
# 56           DS               3 Crossback E-Tense       8.7           93.0
# 57      Renault                         Twingo ZE      12.6           84.0
# 58      Citroen                             e-C4        9.7           93.0
# 59        Tesla               Model S Performance       2.5          162.0
# 60      Renault                     Zoe ZE40 R110      11.4           84.0
# 61        Tesla    Model Y Long Range Performance       3.7          150.0
# 62       Nissan                       Ariya 87kWh       7.6           99.0
# 63       Jaguar                           I-Pace        4.8          124.0
# ...

# %%
# Delete the FastCharge_KmH column
del df['FastCharge_KmH']
df
# Out:
#            Brand                            Model  AccelSec  Top Speed MPH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6          145.0
# 1    Volkswagen                         ID.3 Pure      10.0           99.0
# 2      Polestar                                 2       4.7          130.0
# 3           BMW                              iX3        6.8          112.0
# 4         Honda                                e        9.5           90.0
# ..           ...                              ...       ...            ...
# 98       Nissan                       Ariya 63kWh       7.5           99.0
# 99         Audi     e-tron S Sportback 55 quattro       4.5          130.0
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9          124.0
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1          124.0
# 102       Byton                 M-Byte 95 kWh 2WD       7.5          118.0
#
# ...

# %%
# Assign df variable to a new one to assure it has been cleaned
cleaned_df = df
cleaned_df.head()
# Out:
#          Brand                          Model  AccelSec  Top Speed MPH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6          145.0
# 1  Volkswagen                       ID.3 Pure      10.0           99.0
# 2    Polestar                               2       4.7          130.0
# 3         BMW                            iX3        6.8          112.0
# 4       Honda                              e        9.5           90.0
#
#    Range (miles)  Efficiency WhM RapidCharge PowerTrain    PlugType  \
# 0          280.0           100.0         Yes        AWD  Type 2 CCS
# 1          168.0           104.0         Yes        RWD  Type 2 CCS
# 2          249.0           112.0         Yes        AWD  Type 2 CCS
# 3          224.0           128.0         Yes        RWD  Type 2 CCS
# 4          106.0           104.0         Yes        RWD  Type 2 CCS
#
#    BodyStyle Segment  Seats  Price (USD)
# 0      Sedan       D      5     59918.40
# 1  Hatchback       C      5     32400.00
# ...

# %%
# Sort the cleaned dataframe by Brands
df_sorted = cleaned_df.sort_values(by='Brand')
df_sorted
# Out:
#           Brand                          Model  AccelSec  Top Speed MPH  \
# 49      Aiways                             U5        9.0           93.0
# 87        Audi     e-tron Sportback 50 quattro       6.8          118.0
# 50        Audi               e-tron 55 quattro       5.7          124.0
# 99        Audi   e-tron S Sportback 55 quattro       4.5          130.0
# 42        Audi     e-tron Sportback 55 quattro       5.7          124.0
# ..          ...                            ...       ...            ...
# 95  Volkswagen            ID.3 Pro Performance       7.3           99.0
# 26  Volkswagen                        ID.3 Pro       9.0           99.0
# 17  Volkswagen                          e-Up!       11.9           81.0
# 25  Volkswagen                           ID.4        7.5           99.0
# 27       Volvo            XC40 P8 AWD Recharge       4.9          112.0
#
#     Range (miles)  Efficiency WhM RapidCharge PowerTrain    PlugType  \
# ...

# %%
# Find the average price of an EV per car brand and show the result
average_price_per_brand = df_sorted.groupby("Brand")['Price (USD)'].mean().round()
average_price_per_brand
# Out:
# Brand
# Aiways          38942.0
# Audi            87041.0
# BMW             57397.0
# Byton           64620.0
# CUPRA           48600.0
# Citroen         43200.0
# DS              40416.0
# Fiat            39312.0
# Ford            58934.0
# Honda           37216.0
# Hyundai         39321.0
# Jaguar          81379.0
# Kia             38731.0
# Lexus           54000.0
# Lightyear      160920.0
# Lucid          113400.0
# MG              32400.0
# Mazda           35258.0
# Mercedes        66641.0
# Mini            34215.0
# Nissan          49574.0
# Opel            38179.0
# Peugeot         34583.0
# Polestar        60955.0
# Porsche        149327.0
# Renault         33770.0
# SEAT            21739.0
# Skoda           41316.0
# Smart           24474.0
# Sono            27540.0
# Tesla           86694.0
# Volkswagen      37371.0
# Volvo           65272.0
# Name: Price (USD), dtype: float64

# %%
# Find the avereage electric range of an EV by car brand and show the result
average_range_per_brand = df.groupby("Brand")['Range (miles)'].mean().round()
print(average_range_per_brand)
# Out:
# Brand
# Aiways         208.0
# Audi           222.0
# BMW            198.0
# Byton          231.0
# CUPRA          264.0
# Citroen        155.0
# DS             155.0
# Fiat           155.0
# Ford           246.0
# Honda          106.0
# Hyundai        187.0
# Jaguar         227.0
# Kia            195.0
# Lexus          168.0
# Lightyear      357.0
# Lucid          379.0
# MG             137.0
# Mazda          112.0
# Mercedes       217.0
# Mini           115.0
# Nissan         204.0
# Opel           179.0
# Peugeot        163.0
# Polestar       249.0
# Porsche        241.0
# Renault        145.0
# SEAT           121.0
# Skoda          210.0
# Smart           60.0
# Sono           140.0
# Tesla          311.0
# Volkswagen     198.0
# Volvo          233.0
# Name: Range (miles), dtype: float64

# %%
# Find the average price of an EV by Brand
avg_price = df_sorted.groupby('Brand')['Price (USD)'].mean().reset_index()
avg_price = avg_price.sort_values(by='Price (USD)')

#Graph using new dependency Seaborn
sns.barplot(x='Brand', y='Price (USD)', data= avg_price, palette='colorblind') # Palette is for you, Phil!

plt.xlabel('Car Brands')
plt.ylabel("Average Price (USD)")
plt.title('Average Price of Electric Vehichles by Brand')
plt.tight_layout()
plt.xticks(rotation=90)
plt.savefig('avg_price.png', bbox_inches= 'tight')
plt.show()

# %%
# Find the average range of an EV by Brand
avg_range = df_sorted.groupby('Brand')['Range (miles)'].mean().reset_index()
avg_range = avg_range.sort_values(by='Range (miles)')

# Graph using new dependency Seaborn
sns.barplot(x='Brand', y='Range (miles)', data= avg_range, palette='colorblind') # Palette is for you, Phil!

plt.xlabel('Car Brands')
plt.ylabel("Average Range (Miles)")
plt.title('Average Range of Electric Vehichles by Brand')
plt.tight_layout()
plt.xticks(rotation=90)
plt.savefig('avg_range.png', bbox_inches='tight')
plt.show()

# %%
# Find all of the prices of Tesla Car models
tesla_df = df[df['Brand'] == 'Tesla ']
tesla_df
# Out:
#      Brand                           Model  AccelSec  Top Speed MPH  \
# 0   Tesla    Model 3 Long Range Dual Motor       4.6          145.0
# 8   Tesla      Model 3 Standard Range Plus       5.6          140.0
# 21  Tesla    Model Y Long Range Dual Motor       5.1          135.0
# 24  Tesla   Model 3 Long Range Performance       3.4          162.0
# 33  Tesla             Cybertruck Tri Motor       3.0          130.0
# 40  Tesla               Model S Long Range       3.8          155.0
# 51  Tesla                        Roadster        2.1          255.0
# 54  Tesla               Model X Long Range       4.6          155.0
# 59  Tesla              Model S Performance       2.5          162.0
# 61  Tesla   Model Y Long Range Performance       3.7          150.0
# 67  Tesla            Cybertruck Dual Motor       5.0          118.0
# 81  Tesla              Model X Performance       2.8          155.0
# 86  Tesla          Cybertruck Single Motor       7.0          112.0
#
# ...

# %%
# Drop any duplicate models to ensure a clean graph
unique_models_df = tesla_df.drop_duplicates(subset=['Model'])
unique_models_df
# Out:
#      Brand                           Model  AccelSec  Top Speed MPH  \
# 0   Tesla    Model 3 Long Range Dual Motor       4.6          145.0
# 8   Tesla      Model 3 Standard Range Plus       5.6          140.0
# 21  Tesla    Model Y Long Range Dual Motor       5.1          135.0
# 24  Tesla   Model 3 Long Range Performance       3.4          162.0
# 33  Tesla             Cybertruck Tri Motor       3.0          130.0
# 40  Tesla               Model S Long Range       3.8          155.0
# 51  Tesla                        Roadster        2.1          255.0
# 54  Tesla               Model X Long Range       4.6          155.0
# 59  Tesla              Model S Performance       2.5          162.0
# 61  Tesla   Model Y Long Range Performance       3.7          150.0
# 67  Tesla            Cybertruck Dual Motor       5.0          118.0
# 81  Tesla              Model X Performance       2.8          155.0
# 86  Tesla          Cybertruck Single Motor       7.0          112.0
#
# ...

# %%
# Graph the Price of Tesla Models using Seaborn
sns.barplot(x='Model', y='Price (USD)', data=unique_models_df, palette='colorblind')
plt.xlabel('Models')
plt.ylabel('Price (USD)')
plt.title("Prices of Tesla Models")
plt.tight_layout()
plt.xticks(rotation = 90)
plt.savefig('tesla_model_prices.png', bbox_inches= 'tight')
plt.show()

# %%
df_sorted.head(1)
# Out:
#       Brand Model  AccelSec  Top Speed MPH  Range (miles)  Efficiency WhM  \
# 49  Aiways    U5        9.0           93.0          208.0           117.0
#
#    RapidCharge PowerTrain    PlugType BodyStyle Segment  Seats  Price (USD)
# 49         Yes        FWD  Type 2 CCS       SUV       C      5     38941.56

# %%
# Rename all columns to snake key format
snake_df = df_sorted.rename(columns={'Top Speed MPH': 'Top_Speed_MPH', 'Range (miles)': 'Range_miles', 'Efficiency WhM': 'Efficiency_WhM', 'Price (USD)': 'Price_USD'})

# %%
snake_df.head()
# Out:
#       Brand                          Model  AccelSec  Top_Speed_MPH  \
# 49  Aiways                             U5        9.0           93.0
# 87    Audi     e-tron Sportback 50 quattro       6.8          118.0
# 50    Audi               e-tron 55 quattro       5.7          124.0
# 99    Audi   e-tron S Sportback 55 quattro       4.5          130.0
# 42    Audi     e-tron Sportback 55 quattro       5.7          124.0
#
#     Range_miles  Efficiency_WhM RapidCharge PowerTrain    PlugType BodyStyle  \
# 49        208.0           117.0         Yes        FWD  Type 2 CCS       SUV
# 87        183.0           136.0         Yes        AWD  Type 2 CCS       SUV
# 50        227.0           147.0         Yes        AWD  Type 2 CCS       SUV
# 99        208.0           160.0         Yes        AWD  Type 2 CCS       SUV
# 42        236.0           142.0         Yes        AWD  Type 2 CCS       SUV
#
#    Segment  Seats  Price_USD
# 49       C      5   38941.56
# 87       E      5   75115.08
# ...

# %%
snake_df.to_csv('snake_print.csv', index= False)
print(f"CSV File exported successfully")
# Out:
# CSV File exported successfully
